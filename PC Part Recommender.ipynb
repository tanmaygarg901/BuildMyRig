# %% [markdown]
# ## PC Part Recommender Project by Tanmay
# ### Data Cleaning Part

# %%
import pandas as pd
import numpy as np
import re

# %%
#load all the data from the csv files
cpu = pd.read_csv("cpu.csv")
storage = pd.read_csv("internal-hard-drive.csv")
ram = pd.read_csv("memory.csv")
motherboard = pd.read_csv("motherboard.csv")
psu = pd.read_csv("power-supply.csv")
gpu = pd.read_csv("video-card.csv")
case = pd.read_csv("case.csv")

# %% [markdown]
# ### CPU

# %%
#load and merge cpu benchmark data for ranking
cpu_benchmark = pd.read_csv("CPU_UserBenchmarks.csv")
cpu_benchmark["name"] = cpu_benchmark['Brand'] + " " + cpu_benchmark['Model']
cpu = cpu.dropna(subset='price')
new_cpu = pd.merge(cpu, cpu_benchmark, on='name')
new_cpu = new_cpu.drop(['Type', 'Part Number', 'Model', 'URL', 'Samples'], axis=1).sort_values(by=["Rank"], ascending=True).reset_index()
new_cpu = new_cpu.dropna(subset='boost_clock').reset_index().drop(['level_0', 'index'], axis=1)

cpus_to_keep = [
    'AMD Ryzen 7 7800X3D', 'AMD Ryzen 5 7600X', 'AMD Ryzen 5 5600X',
    'AMD Ryzen 5 7600', 'Intel Core i9-14900K', 'Intel Core i7-14700K',
    'Intel Core i5-12400F', 'AMD Ryzen 5 3600', 'AMD Ryzen 7 7700X',
    'AMD Ryzen 9 7950X3D', 'AMD Ryzen 5 5600', 'AMD Ryzen 7 5800X',
    'Intel Core i5-12600KF', 'AMD Ryzen 5 5500', 'Intel Core i7-12700K',
    'AMD Ryzen 7 5700X', 'Intel Core i7-13700K', 'Intel Core i5-12600K',
    'AMD Ryzen 7 5800X3D', 'AMD Ryzen 9 7900X', 'AMD Ryzen 5 5600G',
    'AMD Ryzen 9 5900X', 'Intel Core i5-13600K', 'Intel Core i9-14900KS',
    'Intel Core i7-12700KF', 'Intel Core i3-12100F', 'Intel Core i5-13600KF',
    'AMD Ryzen 7 7700', 'Intel Core i9-13900K', 'Intel Core i7-14700KF',
    'Intel Core i5-13400F', 'AMD Ryzen 9 7900X3D', 'Intel Core i9-12900K',
    'AMD Ryzen 9 7950X', 'Intel Core i5-14600K', 'Intel Core i7-13700KF',
    'AMD Ryzen 7 5700G', 'AMD Ryzen 9 5950X', 'Intel Core i5-14600KF',
    'Intel Core i9-14900KF', 'Intel Core i5-14400F', 'AMD Ryzen 9 7900',
    'Intel Core i5-14500', 'Intel Core i5-12400', 'Intel Core i7-12700K',
    'Intel Core i3-12100', 'Intel Core i5-13400', 'Intel Core i7-11700K',
    'Intel Core i5-12500', 'Intel Core i7-13700', 'Intel Core i9-11900K',
    'Intel Core i5-10400', 'Intel Core i9-12900KS', 'Intel Core i5-11600K',
    'Intel Core i5-10600K', 'AMD Ryzen 5 5600X3D', 'Intel Core i9-10850K', 
    'AMD Ryzen 5 3600', 'AMD Ryzen 5 3600X', 'AMD Ryzen 7 3700X',
    'AMD Ryzen 9 3900X', 'AMD Ryzen 5 3400G', 'AMD Ryzen 3 3200G',
    'Intel Core i5-9400F', 'Intel Core i5-10400', 'Intel Core i5-10400F',
    'Intel Core i5-10600K', 'Intel Core i7-9700K', 'Intel Core i7-8700K',
    'Intel Core i5-8400', 'AMD Ryzen 5 2600', 'AMD Ryzen 5 2600X',
    'Intel Core i5-9600K'
]

new_cpu = new_cpu[new_cpu.name.isin(cpus_to_keep)].reset_index().drop(['index'], axis=1)

new_cpu.to_csv("new_cpu.csv", index=False)
new_cpu
# Out:
#                      name   price  core_count  core_clock  boost_clock  tdp  \
# 0   Intel Core i9-14900KF  509.14          24         3.2          6.0  125
# 1    Intel Core i9-14900K  544.99          24         3.2          6.0  125
# 2    Intel Core i7-14700K  399.99          20         3.4          5.6  125
# 3   Intel Core i7-14700KF  375.74          20         3.4          5.6  125
# 4    Intel Core i9-13900K  486.59          24         3.0          5.8  125
# ..                    ...     ...         ...         ...          ...  ...
# 64     Intel Core i5-8400  124.00           6         2.8          4.0   65
# 65      AMD Ryzen 5 2600X  195.00           6         3.6          4.2   95
# 66       AMD Ryzen 5 2600  150.00           6         3.4          3.9   65
# 67      AMD Ryzen 5 3400G   98.15           4         3.7          4.2   65
# 68      AMD Ryzen 3 3200G   81.39           4         3.6          4.0   65
#
#                   graphics    smt  Brand  Rank  Benchmark
# 0                      NaN   True  Intel     1      131.0
# 1   Intel UHD Graphics 770   True  Intel     2      131.0
# 2   Intel UHD Graphics 770   True  Intel     4      130.0
# 3                      NaN   True  Intel     5      130.0
# 4   Intel UHD Graphics 770   True  Intel     7      129.0
# ..                     ...    ...    ...   ...        ...
# 64  Intel UHD Graphics 630  False  Intel   202       81.8
# 65                     NaN   True    AMD   309       74.0
# 66                     NaN   True    AMD   320       73.3
# 67          Radeon Vega 11   True    AMD   427       68.1
# 68           Radeon Vega 8  False    AMD   526       62.7
#
# [69 rows x 11 columns]

# %% [markdown]
# ### Motherboard

# %%
#socket type to ensure compatability
socket = ['AM4', 'AM5', 'LGA1700', 'LGA1200', 'LGA1151']
motherboard = motherboard[motherboard['form_factor'] == 'ATX']
motherboard = motherboard.loc[motherboard.socket.isin(socket)].dropna(subset=['price', 'max_memory', 'memory_slots']).reset_index().drop(['index'], axis=1)

motherboard.to_csv("new_motherboard.csv", index=False)
motherboard
# Out:
#                                   name   price   socket form_factor  \
# 0            MSI B650 GAMING PLUS WIFI  169.99      AM5         ATX
# 1    Asus ROG STRIX B650-A GAMING WIFI  199.99      AM5         ATX
# 2            MSI B760 GAMING PLUS WIFI  159.99  LGA1700         ATX
# 3              MSI PRO Z790-A MAX WIFI  239.99  LGA1700         ATX
# 4                 MSI B550 GAMING GEN3   99.99      AM4         ATX
# ..                                 ...     ...      ...         ...
# 354              Supermicro C9Z390-CGW  667.39  LGA1151         ATX
# 355          Supermicro MBD-X11SAE-F-O  495.15  LGA1151         ATX
# 356             ASRock X470 Master SLI  583.33      AM4         ATX
# 357             ASRock Z270 Killer SLI  333.78  LGA1151         ATX
# 358              Supermicro C7Z170-OCE  536.24  LGA1151         ATX
#
#      max_memory  memory_slots           color
# 0           192             4           Black
# 1           192             4  Black / Silver
# 2           192             4  Black / Silver
# 3           192             4  Silver / Black
# 4           128             4           Black
# ..          ...           ...             ...
# 354         128             4  Black / Silver
# 355          64             4   Black / Green
# 356          64             4           Black
# 357          64             4   Black / White
# 358          64             4   Black / Green
#
# [359 rows x 7 columns]

# %% [markdown]
# ### Memory

# %%
ram = ram.dropna(subset='price')
ram[['num_sticks', 'ram_size_per_stick']] = ram['modules'].str.split(',', expand=True)
ram[['DDR', 'speed']] = ram['speed'].str.split(',', expand=True)
ram['num_sticks'] = ram['num_sticks'].astype(int)
ram['ram_size_per_stick'] = ram['ram_size_per_stick'].astype(int)
ram['total_ram'] = ram['num_sticks'] * ram['ram_size_per_stick']
ram = ram.where(ram['total_ram'] >= 8).dropna().reset_index().drop(['index'], axis=1)
ram = ram.drop(['price_per_gb', 'color', 'modules'], axis=1)
ram = ram[ram.total_ram <= 64].reset_index().drop(['index'], axis=1)
ram['DDR'] = ram.DDR.astype(int)
ram = ram[ram.DDR >= 4].reset_index().drop(['index'], axis=1)
ram.to_csv("new_ram.csv", index=False)
ram
# Out:
#                                           name   price speed  \
# 0                  Corsair Vengeance LPX 16 GB   38.99  3200
# 1                      Corsair Vengeance 32 GB  113.99  5600
# 2                 G.Skill Trident Z5 RGB 32 GB  117.99  6000
# 3                      Corsair Vengeance 32 GB  114.99  6000
# 4              Corsair Vengeance RGB Pro 32 GB   94.99  3600
# ...                                        ...     ...   ...
# 2259              V-Color TRA516G68S834Q 64 GB  509.99  6800
# 2260          Kingston FURY Renegade Pro 16 GB   96.93  5600
# 2261          Kingston FURY Renegade Pro 32 GB  174.54  6000
# 2262          Kingston FURY Renegade Pro 64 GB  429.99  6400
# 2263  ADATA XPG LANCER RGB ROG CERTIFIED 32 GB  159.99  6600
#
#       first_word_latency  cas_latency  num_sticks  ram_size_per_stick  DDR  \
# 0                 10.000         16.0         2.0                 8.0    4
# 1                 12.857         36.0         2.0                16.0    5
# 2                 12.000         36.0         2.0                16.0    5
# 3                 10.000         30.0         2.0                16.0    5
# 4                 10.000         18.0         2.0                16.0    4
# ...                  ...          ...         ...                 ...  ...
# 2259              10.000         34.0         4.0                16.0    5
# 2260              13.571         38.0         1.0                16.0    5
# 2261              10.667         32.0         1.0                32.0    5
# 2262              10.000         32.0         4.0                16.0    5
# 2263               9.697         32.0         2.0                16.0    5
#
#       total_ram
# 0          16.0
# 1          32.0
# 2          32.0
# 3          32.0
# 4          32.0
# ...         ...
# 2259       64.0
# 2260       16.0
# 2261       32.0
# 2262       64.0
# 2263       32.0
#
# [2264 rows x 9 columns]

# %% [markdown]
# ### Storage

# %%
storage = storage.dropna(subset=['price', 'capacity']).reset_index().drop(['index'], axis=1)
storage['capacity_2'] = [f'{cap/1000} TB' if cap >= 1000 else f'{cap} GB' for cap in storage['capacity']]
uncommon_storage = [
    '16.0 TB', '24.0 TB', '8.0 TB', '1.2 TB', '2.048 TB', '12.0 TB',
    '18.0 TB', '6.0 TB', '22.0 TB', '10.0 TB', '20.0 TB', '1.6 TB',
    '1.02 TB', '5.0 TB', '4.096 TB', '14.0 TB', '7.68 TB', '1.92 TB',
    '1.05 TB', '3.84 TB', '1.5 TB', '1.8 TB', '1.9 TB', '2.4 TB',
    '3.2 TB', '3.8 TB', '32.0 GB', '40.0 GB', '64.0 GB', '80.0 GB',
    '100.0 GB', '118.0 GB', '146.0 GB', '150.0 GB', '180.0 GB',
    '200.0 GB', '275.0 GB', '300.0 GB', '320.0 GB', '360.0 GB',
    '400.0 GB', '460.0 GB', '600.0 GB', '640.0 GB', '750.0 GB',
    '800.0 GB', '900.0 GB', '1.024 TB','2.05 TB','60.0 GB','160.0 GB'
]
supported_storage = [
    'M.2 PCIe 4.0 X4',
    'M.2 PCIe 3.0 X4',
    'SATA 6.0 Gb/s',
    'M.2 SATA',
    'PCIe x8',
    'PCIe x4',
    'M.2 PCIe 3.0 X2',
]

storage = storage[~storage['capacity_2'].isin(uncommon_storage)]
storage = storage[storage.type == 'SSD']
storage = storage[storage['interface'].isin(supported_storage)].reset_index().drop(['index'], axis=1)

storage.to_csv("new_storage.csv", index=False)
storage
# Out:
#                       name  storage_price  capacity  price_per_gb type  \
# 0          Samsung 980 Pro         169.99    2000.0         0.085  SSD
# 1             Kingston NV2          60.99    1000.0         0.061  SSD
# 2     Samsung 970 Evo Plus          97.50    1000.0         0.098  SSD
# 3          Samsung 990 Pro         318.35    4000.0         0.080  SSD
# 4          Crucial P3 Plus          69.98    1000.0         0.070  SSD
# ...                    ...            ...       ...           ...  ...
# 1182        VisionTek DLX4          96.99    1000.0         0.097  SSD
# 1183        Transcend 830S         109.99    1000.0         0.110  SSD
# 1184      VisionTek 900981         149.16    1000.0         0.149  SSD
# 1185      VisionTek 900982         288.64    2000.0         0.144  SSD
# 1186          Lenovo S4520         299.00     480.0         0.623  SSD
#
#        cache form_factor        interface capacity_2
# 0     2048.0    M.2-2280  M.2 PCIe 4.0 X4     2.0 TB
# 1        NaN    M.2-2280  M.2 PCIe 4.0 X4     1.0 TB
# 2     1024.0    M.2-2280  M.2 PCIe 3.0 X4     1.0 TB
# 3     4096.0    M.2-2280  M.2 PCIe 4.0 X4     4.0 TB
# 4        NaN    M.2-2280  M.2 PCIe 4.0 X4     1.0 TB
# ...      ...         ...              ...        ...
# 1182     NaN    M.2-2230  M.2 PCIe 4.0 X4     1.0 TB
# 1183     NaN    M.2-2280         M.2 SATA     1.0 TB
# 1184     NaN         2.5    SATA 6.0 Gb/s     1.0 TB
# 1185     NaN         2.5    SATA 6.0 Gb/s     2.0 TB
# 1186     NaN         2.5    SATA 6.0 Gb/s   480.0 GB
#
# [1187 rows x 9 columns]

# %% [markdown]
# ### GPU

# %%
#gpu filtering
gpu = gpu.drop(['color', 'Type', 'Part Number', 'Samples', 'URL'], axis=1)
a = gpu.dropna().reset_index().drop(['index'], axis=1)

#removing obsolete / special use case models
outdated_nvidia = ['GTX 10', 'GTX 9', 'GTX 7', 'GTX 6', 'GT']
outdated_amd = ['RX 5', 'R9', 'R7', 'HD']
outdated_gpus = ['RX 480','RX Vega-56', 'RX Vega-64','RX 470', 'RX 460']
professional = ['Quadro RTX 8000','Titan RTX','Quadro RTX 5000','Quadro RTX 4000','Quadro RTX 6000','Quadro P4000','Quadro P2000','Quadro P1000','Titan Xp','Titan V','Quadro M2000','Quadro P5000','Quadro K600']
outdated_other = ['GeForce 8400 GS','Quadro M6000 24GB','FirePro 2270','Quadro M4000','Quadro K4200','Radeon-VII','Quadro FX 1800','Vega Frontier Edition','Quadro P6000','Quadro K2200','Quadro K620','Quadro K5200','Quadro K1200','Quadro K4000','4 Series Internal Chipset','Quadro 2000','Quadro 4000','Quadro K6000','NVS 510','GeForce 210','Quadro K2000','Quadro NVS 450','FirePro W9000','Quadro M6000','FirePro W7000','Quadro 5000','Quadro 6000','Quadro GP100','Radeon R5','Quadro NVS 295','Quadro K5000','Quadro 400','FirePro V4900','GeForce MX350','Quadro K4000M']
outdated_keywords = outdated_nvidia + outdated_amd + outdated_other + professional + outdated_gpus
filtered_df = a[~a['Model'].str.contains('|'.join(outdated_keywords), case=False, na=False)]
filtered_df = filtered_df.dropna().reset_index().drop(['index'], axis=1)

#more gpus with obsolete/special chipsets
gpus_to_drop = [
    'RTX 6000 Ada Generation',
    'RTX A6000',
    'RTX A5500',
    'RTX A5000',
    'RTX A4500',
    'RTX A4000',
    'RTX A2000 12GB',
    'RTX A2000 6GB',
    'RTX 4000 SFF Ada Generation',
    'T1000 8GB',
    'Radeon Pro WX 3100',
    'Radeon Pro WX 4100',
    'Radeon Pro WX 7100',
    'Radeon Pro WX 3200',
    'Radeon Pro VII',
    'Radeon Pro WX 5100',
    'Radeon Pro WX 2100',
    'Radeon Pro WX 9100',
    'Radeon Pro WX 8200',
    'Radeon PRO W7900',
    'Radeon PRO W7800',
    'Radeon PRO W7600',
    'Radeon PRO W7500',
    'Radeon PRO W6800',
    'Radeon PRO W6600',
    'Radeon PRO W6400',
    'Radeon Pro W5500',
    'Radeon Pro W5700',
    'Arc A380',
    'Arc A310'
]
filtered_df = filtered_df[~filtered_df['chipset'].isin(gpus_to_drop)]

power_consumption = {
    'RTX 3060': 170,
    'RTX 4070': 200,
    'RX 6700-XT': 230,
    'RTX 4060': 115,
    'RTX 4090': 450,
    'RTX 4070-Ti': 285,
    'RX 7800-XT': 270,
    'RX 7900-XTX': 355,
    'RX 6800': 250,
    'RX 7900-XT': 300,
    'RX 6600': 132,
    'RTX 3070': 220,
    'RTX 4080': 320,
    'RX 6750-XT': 250,
    'RTX 3050': 130,
    'RTX 3060-Ti': 200,
    'RTX 4060-Ti': 160,
    'RX 7700-XT': 245,
    'RX 7600': 165,
    'RX 6650-XT': 180,
    'RX 6800-XT': 300,
    'RTX 3080': 320,
    'RX 6600-XT': 160,
    'RTX 2060': 160,
    'Arc A770': 225,
    'RX 6500-XT': 107,
    'RTX 3080-Ti': 350,
    'RX 6950-XT': 335,
    'RTX 3070-Ti': 290,
    'RTX 3090': 350,
    'RTX 2070': 175,
    'RTX 3090-Ti': 450,
    'RTX 2080-Ti': 250,
    'Arc A580': 165,
    'RTX 2080': 215,
    'RX 6900-XT': 300,
    'Gigabyte RTX 3060 Ti 8GB Gaming OC Pro': 200,
    'Arc A380': 75,
    'Arc A750': 225,
    'Asus RTX 3070 Ti 8GB Tuf OC': 290 
}

filtered_df = filtered_df.drop(['best_match_model', 'merge_key'], axis=1)
filtered_df['tdp'] = filtered_df['Model'].map(power_consumption)
filtered_df = filtered_df.dropna(subset=['tdp', 'Rank']).reset_index().drop(['index',], axis=1)
filtered_df.to_csv("new_gpu.csv", index=False)
filtered_df
# Out:
#                                    name    price                chipset  \
# 0    MSI GeForce RTX 3060 Ventus 2X 12G   289.39  GeForce RTX 3060 12GB
# 1                 Gigabyte WINDFORCE OC   549.99       GeForce RTX 4070
# 2        ASRock Radeon RX6700XT CLD 12G   375.99      Radeon RX 6700 XT
# 3                          Asus DUAL OC   309.99       GeForce RTX 4060
# 4              Asus ROG STRIX GAMING OC  2313.98       GeForce RTX 4090
# ..                                  ...      ...                    ...
# 570        XFX Speedster QICK 319 BLACK   846.99         Radeon RX 6800
# 571         Inno3D N30602-08D6-11902130   335.53   GeForce RTX 3050 8GB
# 572          Asus STRIX GAMING Advanced   675.00       GeForce RTX 2070
# 573               EVGA XC3 BLACK GAMING   789.99   GeForce RTX 3070 LHR
# 574                     Palit GamingPro   879.27       GeForce RTX 4070
#
#      memory  core_clock  boost_clock  length   Brand       Model  Rank  \
# 0      12.0      1320.0       1777.0   235.0  Nvidia    RTX 3060    59
# 1      12.0      1920.0       2490.0   261.0  Nvidia    RTX 4070    14
# 2      12.0      2321.0       2581.0   269.0     AMD  RX 6700-XT    40
# 3       8.0      1830.0       2535.0   227.0  Nvidia    RTX 4060    39
# 4      24.0      2235.0       2640.0   358.0  Nvidia    RTX 4090     1
# ..      ...         ...          ...     ...     ...         ...   ...
# 570    16.0      1850.0       2190.0   340.0     AMD     RX 6800    27
# 571     8.0      1320.0       1777.0   240.0  Nvidia    RTX 3050    92
# 572     8.0      1410.0       1680.0   300.0  Nvidia    RTX 2070    55
# 573     8.0      1500.0       1725.0   285.0  Nvidia    RTX 3070    25
# 574    12.0      1920.0       2475.0   329.0  Nvidia    RTX 4070    14
#
#      Benchmark  tdp
# 0        100.0  170
# 1        190.0  200
# 2        122.0  230
# 3        122.0  115
# 4        370.0  450
# ..         ...  ...
# 570      143.0  250
# 571       74.8  130
# 572      104.0  175
# 573      148.0  220
# 574      190.0  200
#
# [575 rows x 12 columns]

# %% [markdown]
# ### Power Supply

# %%
psu = psu.dropna().reset_index().drop(['index'], axis=1)
wattages_to_keep = [550, 650, 750, 850, 1000, 1200]
psu = psu[psu['wattage'].isin(wattages_to_keep)]
psu = psu[psu.type == 'ATX'].reset_index().drop(['index'], axis=1)
psu.to_csv("new_psu.csv", index=False)
psu
# Out:
#                                  name   price type efficiency  wattage  \
# 0               Corsair RM750e (2023)   99.99  ATX       gold      750
# 1               Corsair RM850e (2023)  119.99  ATX       gold      850
# 2              Corsair RM1000e (2023)  159.99  ATX       gold     1000
# 3                Corsair RM650 (2023)   89.99  ATX       gold      650
# 4                      MSI MAG A650BN   59.00  ATX     bronze      650
# ..                                ...     ...  ...        ...      ...
# 381  Super Flower Leadex III ARGB Pro  164.99  ATX       gold      650
# 382  Super Flower Leadex III ARGB Pro  189.99  ATX       gold      750
# 383       Fractal Design Anode Bronze  145.49  ATX     bronze      550
# 384        Enermax Revolution D.F. 12  129.99  ATX       gold      750
# 385              Chieftec Polaris 3.0  176.68  ATX       gold      850
#
#     modular  color
# 0      Full  Black
# 1      Full  Black
# 2      Full  Black
# 3      Full  Black
# 4     false  Black
# ..      ...    ...
# 381    Full  Black
# 382    Full  Black
# 383    Semi  Black
# 384    Full  Black
# 385    Full  Black
#
# [386 rows x 7 columns]

# %% [markdown]
# ### Case

# %%
case = case.dropna(subset='price').reset_index().drop(['index'], axis=1)
case = case.drop(['psu', 'external_volume'], axis=1)
cases_to_keep = ['ATX Mid Tower', 'ATX Full Tower']
case_max_gpu_length = {
    'ATX Mid Tower': 330,
    'ATX Full Tower': 400,
}
case = case[case['type'].isin(cases_to_keep)]
case['max_gpu_length'] = case['type'].map(case_max_gpu_length).reset_index().drop(['index'], axis=1)
case.to_csv("new_case.csv", index=False)
case
# Out:
#                                          name  case_price           type  \
# 0                       Corsair 4000D Airflow      104.99  ATX Mid Tower
# 1                                NZXT H5 Flow       94.99  ATX Mid Tower
# 2                                NZXT H9 Flow      159.99  ATX Mid Tower
# 3                                NZXT H9 Flow      154.99  ATX Mid Tower
# 4                         Montech AIR 903 MAX       75.00  ATX Mid Tower
# ..                                        ...         ...            ...
# 767                        Silverstone PM02-G      136.99  ATX Mid Tower
# 768  Thermaltake Divider 500 TG ARGB Air Snow      164.98  ATX Mid Tower
# 769                   RAIJINTEK PAEAN PREMIUM      219.90  ATX Mid Tower
# 770       Thermaltake Divider 300 TG Air Snow      119.99  ATX Mid Tower
# 771                        Cougar MX660-T RGB      170.96  ATX Mid Tower
#
#       color             side_panel  internal_35_bays  case_max_gpu_length  \
# 0     Black  Tinted Tempered Glass                 2                330.0
# 1     Black         Tempered Glass                 1                330.0
# 2     White         Tempered Glass                 2                330.0
# 3     Black         Tempered Glass                 2                330.0
# 4     Black         Tempered Glass                 2                330.0
# ..      ...                    ...               ...                  ...
# 767     NaN         Tempered Glass                 3                  NaN
# 768   White         Tempered Glass                 2                  NaN
# 769  Silver         Tempered Glass                 2                  NaN
# 770   White         Tempered Glass                 2                  NaN
# 771   Black         Tempered Glass                 2                  NaN
#
#      max_gpu_length
# 0               330
# 1               330
# 2               330
# 3               330
# 4               330
# ..              ...
# 767             330
# 768             330
# 769             330
# 770             330
# 771             330
#
# [772 rows x 8 columns]

# %% [markdown]
# ## Adding additional features to help with model and comptability

# %%
#loading the cleaned datasets for gpu 
gpus = pd.read_csv("new_gpu.csv")
#adding a column for price/performance ratio using core clock data
cc2p = gpus.core_clock / gpus.price
bc2p = gpus.boost_clock / gpus.price
gpus['avg_p2p'] = (cc2p + bc2p)/2    #this is the average price-to-performance calculation using the clock speeds and prices
gpus.to_csv("new_gpu_with_features.csv", index=False)
gpus
#gpus[gpus.price <= 567.996].sort_values(by=['Rank', 'price', 'avg_p2p'], ascending=[True, True, False])   filter test
# Out:
#                                    name    price                chipset  \
# 0    MSI GeForce RTX 3060 Ventus 2X 12G   289.39  GeForce RTX 3060 12GB
# 1                 Gigabyte WINDFORCE OC   549.99       GeForce RTX 4070
# 2        ASRock Radeon RX6700XT CLD 12G   375.99      Radeon RX 6700 XT
# 3                          Asus DUAL OC   309.99       GeForce RTX 4060
# 4              Asus ROG STRIX GAMING OC  2313.98       GeForce RTX 4090
# ..                                  ...      ...                    ...
# 570        XFX Speedster QICK 319 BLACK   846.99         Radeon RX 6800
# 571         Inno3D N30602-08D6-11902130   335.53   GeForce RTX 3050 8GB
# 572          Asus STRIX GAMING Advanced   675.00       GeForce RTX 2070
# 573               EVGA XC3 BLACK GAMING   789.99   GeForce RTX 3070 LHR
# 574                     Palit GamingPro   879.27       GeForce RTX 4070
#
#      memory  core_clock  boost_clock  length   Brand       Model  Rank  \
# 0      12.0      1320.0       1777.0   235.0  Nvidia    RTX 3060    59
# 1      12.0      1920.0       2490.0   261.0  Nvidia    RTX 4070    14
# 2      12.0      2321.0       2581.0   269.0     AMD  RX 6700-XT    40
# 3       8.0      1830.0       2535.0   227.0  Nvidia    RTX 4060    39
# 4      24.0      2235.0       2640.0   358.0  Nvidia    RTX 4090     1
# ..      ...         ...          ...     ...     ...         ...   ...
# 570    16.0      1850.0       2190.0   340.0     AMD     RX 6800    27
# 571     8.0      1320.0       1777.0   240.0  Nvidia    RTX 3050    92
# 572     8.0      1410.0       1680.0   300.0  Nvidia    RTX 2070    55
# 573     8.0      1500.0       1725.0   285.0  Nvidia    RTX 3070    25
# 574    12.0      1920.0       2475.0   329.0  Nvidia    RTX 4070    14
#
#      Benchmark  tdp   avg_p2p
# 0        100.0  170  5.350911
# 1        190.0  200  4.009164
# 2        122.0  230  6.518790
# 3        122.0  115  7.040550
# 4        370.0  450  1.053380
# ..         ...  ...       ...
# 570      143.0  250  2.384916
# 571       74.8  130  4.615087
# 572      104.0  175  2.288889
# 573      148.0  220  2.041165
# 574      190.0  200  2.499232
#
# [575 rows x 13 columns]

# %%
#same for cpu
cpus = pd.read_csv("new_cpu.csv")
cc2p = cpus.core_clock / cpus.price
bc2p = cpus.boost_clock / cpus.price
cpus['avg_p2p'] = ((cc2p+bc2p)/2)*100

def get_socket(cpu_name):
    if any(x in cpu_name for x in ['Ryzen 9 7', 'Ryzen 7 7', 'Ryzen 5 7']):
        return 'AM5'
    if 'Ryzen' in cpu_name:
        return 'AM4'
    if 'Core' in cpu_name:
        parts = cpu_name.split('-')
        if len(parts) > 1:
            gen_part = parts[1].split('K')[0] 
            if len(gen_part) > 1 and gen_part[0] == '1':
                gen = int(gen_part[:2]) 
            else:
                gen = int(gen_part[0]) 
            if gen >= 12:
                return 'LGA1700'
            if gen in [10, 11]:
                return 'LGA1200'
            return 'LGA1151'

cpus['socket'] = cpus['name'].apply(get_socket)

cpus.to_csv("new_cpu_with_features.csv", index=False)
cpus
cpus[cpus.price <= 500].sort_values(by=['Rank', 'price', 'avg_p2p'], ascending=[True, True, False])
# Out:
#                      name   price  core_count  core_clock  boost_clock  tdp  \
# 2    Intel Core i7-14700K  399.99          20         3.4          5.6  125
# 3   Intel Core i7-14700KF  375.74          20         3.4          5.6  125
# 4    Intel Core i9-13900K  486.59          24         3.0          5.8  125
# 5   Intel Core i7-13700KF  303.49          16         3.4          5.4  125
# 6    Intel Core i7-13700K  359.00          16         3.4          5.4  125
# ..                    ...     ...         ...         ...          ...  ...
# 63     Intel Core i5-8400  249.95           6         2.8          4.0   65
# 65      AMD Ryzen 5 2600X  195.00           6         3.6          4.2   95
# 66       AMD Ryzen 5 2600  150.00           6         3.4          3.9   65
# 67      AMD Ryzen 5 3400G   98.15           4         3.7          4.2   65
# 68      AMD Ryzen 3 3200G   81.39           4         3.6          4.0   65
#
#                   graphics    smt  Brand  Rank  Benchmark   avg_p2p   socket
# 2   Intel UHD Graphics 770   True  Intel     4      130.0  1.125028  LGA1700
# 3                      NaN   True  Intel     5      130.0  1.197637  LGA1700
# 4   Intel UHD Graphics 770   True  Intel     7      129.0  0.904252  LGA1700
# 5                      NaN   True  Intel     8      126.0  1.449801  LGA1700
# 6   Intel UHD Graphics 770   True  Intel     9      126.0  1.225627  LGA1700
# ..                     ...    ...    ...   ...        ...       ...      ...
# 63  Intel UHD Graphics 630  False  Intel   202       81.8  1.360272  LGA1151
# 65                     NaN   True    AMD   309       74.0  2.000000      AM4
# 66                     NaN   True    AMD   320       73.3  2.433333      AM4
# 67          Radeon Vega 11   True    AMD   427       68.1  4.024452      AM4
# 68           Radeon Vega 8  False    AMD   526       62.7  4.668878      AM4
#
# [65 rows x 13 columns]

# %%
rams = pd.read_csv("new_ram.csv")
rams['speed_to_price'] = rams.speed / rams.price
rams['total_ram_to_price'] = rams.total_ram / rams.price
rams.to_csv("new_ram_with_features.csv", index=False)
rams
# Out:
#                                           name   price  speed  \
# 0                  Corsair Vengeance LPX 16 GB   38.99   3200
# 1                      Corsair Vengeance 32 GB  113.99   5600
# 2                 G.Skill Trident Z5 RGB 32 GB  117.99   6000
# 3                      Corsair Vengeance 32 GB  114.99   6000
# 4              Corsair Vengeance RGB Pro 32 GB   94.99   3600
# ...                                        ...     ...    ...
# 2259              V-Color TRA516G68S834Q 64 GB  509.99   6800
# 2260          Kingston FURY Renegade Pro 16 GB   96.93   5600
# 2261          Kingston FURY Renegade Pro 32 GB  174.54   6000
# 2262          Kingston FURY Renegade Pro 64 GB  429.99   6400
# 2263  ADATA XPG LANCER RGB ROG CERTIFIED 32 GB  159.99   6600
#
#       first_word_latency  cas_latency  num_sticks  ram_size_per_stick  DDR  \
# 0                 10.000         16.0         2.0                 8.0    4
# 1                 12.857         36.0         2.0                16.0    5
# 2                 12.000         36.0         2.0                16.0    5
# 3                 10.000         30.0         2.0                16.0    5
# 4                 10.000         18.0         2.0                16.0    4
# ...                  ...          ...         ...                 ...  ...
# 2259              10.000         34.0         4.0                16.0    5
# 2260              13.571         38.0         1.0                16.0    5
# 2261              10.667         32.0         1.0                32.0    5
# 2262              10.000         32.0         4.0                16.0    5
# 2263               9.697         32.0         2.0                16.0    5
#
#       total_ram  speed_to_price  total_ram_to_price
# 0          16.0       82.072326            0.410362
# 1          32.0       49.127116            0.280726
# 2          32.0       50.851767            0.271209
# 3          32.0       52.178450            0.278285
# 4          32.0       37.898726            0.336878
# ...         ...             ...                 ...
# 2259       64.0       13.333595            0.125493
# 2260       16.0       57.773651            0.165068
# 2261       32.0       34.376074            0.183339
# 2262       64.0       14.884067            0.148841
# 2263       32.0       41.252578            0.200013
#
# [2264 rows x 11 columns]
